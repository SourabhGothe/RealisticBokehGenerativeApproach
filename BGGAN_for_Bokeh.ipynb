# %% [markdown]
# #Imports and directory mounting

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
from tensorflow import keras
import tensorflow as tf
import tensorflow.keras.backend as K
import tensorflow as tf
import glob, os
import argparse
import matplotlib.pyplot as plt

# %% [markdown]
# #Model class creation

# %%
class InstanceNormalization(tf.keras.models.Model):
    def __init__(self,epsilon=1e-5,
                 **kwargs):
        super(InstanceNormalization, self).__init__(**kwargs)
        self.epsilon = epsilon

    def build(self, input_shape):  
        assert len(input_shape)==4
        shape = (input_shape[-1],)
        self.built = True
        # self.pool = tf.keras.layers.AveragePooling2D(pool_size = (input_shape[1],input_shape[2]),padding='valid')

    def call(self,inputs):
        if inputs.shape[1] == None:
            return inputs
        else:
            mean = tf.keras.layers.AveragePooling2D(pool_size=(inputs.shape[1],inputs.shape[2]))(inputs)
            # print(type(mean),mean)
            mean = tf.keras.layers.Reshape(target_shape=(1,1,inputs.shape[-1]))(mean)
            variance = tf.keras.layers.AveragePooling2D(pool_size=(inputs.shape[1],inputs.shape[2]))((inputs-mean)*(inputs-mean))*inputs.shape[1]*inputs.shape[2]
            variance =tf.keras.layers.Reshape(target_shape=(1,1,inputs.shape[-1]))(variance)
            outputs = (inputs - mean) / (tf.exp(0.5*tf.math.log(variance + self.epsilon))) 

        return outputs

def res_block(input, filters, kernel_size=(3, 3), strides=(1, 1), normlization='InstanceNormalization'):
    initializer = tf.random_normal_initializer(0., 0.02)
    ## step size 1 , keep the feature size
    x = keras.layers.Conv2D(filters=filters,kernel_size=kernel_size, strides=strides, padding='same',kernel_initializer=initializer, use_bias=False)(input)    
    if normlization == 'batcnorm':
        x = keras.layers.BatchNormalization(momentum=0.0)(x,training=True)
    elif normlization == 'InstanceNormalization':
        x = InstanceNormalization()(x)
    x = keras.layers.Activation('relu')(x)
    x = keras.layers.Dropout(0.1)(x)
    x = keras.layers.Conv2D(filters=filters, kernel_size=kernel_size, strides=strides,padding='same',kernel_initializer=initializer, use_bias=False)(x)    
    if normlization == 'batcnorm':
        x = keras.layers.BatchNormalization(momentum=0.0)(x,training=True)
    elif normlization == 'InstanceNormalization':
        x = InstanceNormalization()(x)
    out = keras.layers.Add()([input, x])#residual block
    out = keras.layers.Activation('relu')(out)
    return out

def Conv_block(input, filters, kernel_size=(3, 3), strides=(2, 2),iftanh=False):
    initializer = tf.random_normal_initializer(0., 0.02)
    if iftanh:
        x = keras.layers.Conv2D(filters=filters,kernel_size=kernel_size, strides=strides, padding='same',kernel_initializer=initializer,activation='tanh', use_bias=False)(input) 
    else:
        x = keras.layers.Conv2D(filters=filters,kernel_size=kernel_size, strides=strides, padding='same',kernel_initializer=initializer, use_bias=False)(input)
        x = keras.layers.Activation('relu')(x)
    return x

def deconv_Relu(input,filters):
    x = keras.layers.Conv2DTranspose(filters,4,2,'same')(input)
    x = keras.layers.Activation('relu')(x)
    return x

def resnet(x,filters,num_block):
    for _ in tf.range(num_block):
        x = res_block(x,filters)
    return x

def model1(x,c,num_block):
    x1 = Conv_block(x,filters=c,strides=(1,1))
    x2 = Conv_block(x1,2*c)
    x3 = Conv_block(x2,4*c)
    x4 = Conv_block(x3,8*c)
    resout = resnet(x4,8*c,num_block)
    
    y1_0 = keras.layers.concatenate([resout,x4],3)
    y1_0 = deconv_Relu(y1_0,c*4)

    y1_1 = deconv_Relu(y1_0,c*2)
    y1_2 = deconv_Relu(y1_1,c)

    y_out1 = Conv_block(y1_2,3,strides=(1,1),iftanh=True)
    return y_out1

def model2(x,x2,c,num_block):

    x1_0 = keras.layers.concatenate([x2,x-x2],3)
    x1_0 = Conv_block(x1_0,c,strides=(1,1))
    x1_1 = Conv_block(x1_0,c*2)
    x1_2 = Conv_block(x1_1,c*4)
    x1_3 = Conv_block(x1_2,c*8)

    x_merge = x1_3
    x_merge = Conv_block(x_merge,c*8,strides=(1,1))
    x_resnet = resnet(x_merge,c*8,num_block=num_block)


    y1_0 = deconv_Relu(keras.layers.concatenate([x1_3,x_resnet],3),c*4)
    y1_1 = deconv_Relu(keras.layers.concatenate([x1_2,    y1_0],3),c*2)
    y1_2 = deconv_Relu(keras.layers.concatenate([x1_1,    y1_1],3),c*1) 

    gt = Conv_block(y1_2,3,strides=(1,1),iftanh=True)

    return(gt)

def xnet(c1=16,c2=24,res_num_block=9):
    inputs = keras.layers.Input(name='blur_image' ,shape=(None,None,3))
    y_out1=model1(inputs,c1,res_num_block)
    output = model2(inputs,y_out1,c2,res_num_block)
    model = keras.models.Model(inputs = inputs, outputs = [output, y_out1], name='Discriminator')
    return model

# %%
# inputs = keras.layers.Input(shape=(1024,1408,3))
model = xnet()
model.summary()
# Out:
# Model: "Discriminator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  blur_image (InputLayer)        [(None, None, None,  0           []
#                                  3)]
#
#  conv2d_47 (Conv2D)             (None, None, None,   432         ['blur_image[0][0]']
#                                 16)
#
#  activation_51 (Activation)     (None, None, None,   0           ['conv2d_47[0][0]']
#                                 16)
#
#  conv2d_48 (Conv2D)             (None, None, None,   4608        ['activation_51[0][0]']
#                                 32)
#
#  activation_52 (Activation)     (None, None, None,   0           ['conv2d_48[0][0]']
#                                 32)
#
#  conv2d_49 (Conv2D)             (None, None, None,   18432       ['activation_52[0][0]']
#                                 64)
#
#  activation_53 (Activation)     (None, None, None,   0           ['conv2d_49[0][0]']
#                                 64)
#
#  conv2d_50 (Conv2D)             (None, None, None,   73728       ['activation_53[0][0]']
#                                 128)
#
#  activation_54 (Activation)     (None, None, None,   0           ['conv2d_50[0][0]']
#                                 128)
#
#  conv2d_51 (Conv2D)             (None, None, None,   147456      ['activation_54[0][0]']
#                                 128)
#
#  instance_normalization_36 (Ins  (None, None, None,   0          ['conv2d_51[0][0]']
#  tanceNormalization)            128)
#
#  activation_55 (Activation)     (None, None, None,   0           ['instance_normalization_36[0][0]
#                                 128)                             ']
#
#  dropout_18 (Dropout)           (None, None, None,   0           ['activation_55[0][0]']
#                                 128)
#
#  conv2d_52 (Conv2D)             (None, None, None,   147456      ['dropout_18[0][0]']
#                                 128)
#
#  instance_normalization_37 (Ins  (None, None, None,   0          ['conv2d_52[0][0]']
#  tanceNormalization)            128)
#
#  add_18 (Add)                   (None, None, None,   0           ['activation_54[0][0]',
#                                 128)                              'instance_normalization_37[0][0]
#                                                                  ']
#
#  activation_56 (Activation)     (None, None, None,   0           ['add_18[0][0]']
#                                 128)
#
#  conv2d_53 (Conv2D)             (None, None, None,   147456      ['activation_56[0][0]']
#                                 128)
#
#  instance_normalization_38 (Ins  (None, None, None,   0          ['conv2d_53[0][0]']
#  tanceNormalization)            128)
#
#  activation_57 (Activation)     (None, None, None,   0           ['instance_normalization_38[0][0]
#                                 128)                             ']
#
#  dropout_19 (Dropout)           (None, None, None,   0           ['activation_57[0][0]']
#                                 128)
#
#  conv2d_54 (Conv2D)             (None, None, None,   147456      ['dropout_19[0][0]']
#                                 128)
#
#  instance_normalization_39 (Ins  (None, None, None,   0          ['conv2d_54[0][0]']
#  tanceNormalization)            128)
#
#  add_19 (Add)                   (None, None, None,   0           ['activation_56[0][0]',
#                                 128)                              'instance_normalization_39[0][0]
#                                                                  ']
#
#  activation_58 (Activation)     (None, None, None,   0           ['add_19[0][0]']
#                                 128)
#
#  conv2d_55 (Conv2D)             (None, None, None,   147456      ['activation_58[0][0]']
#                                 128)
#
#  instance_normalization_40 (Ins  (None, None, None,   0          ['conv2d_55[0][0]']
#  tanceNormalization)            128)
#
#  activation_59 (Activation)     (None, None, None,   0           ['instance_normalization_40[0][0]
#                                 128)                             ']
#
#  dropout_20 (Dropout)           (None, None, None,   0           ['activation_59[0][0]']
#                                 128)
#
#  conv2d_56 (Conv2D)             (None, None, None,   147456      ['dropout_20[0][0]']
#                                 128)
#
#  instance_normalization_41 (Ins  (None, None, None,   0          ['conv2d_56[0][0]']
#  tanceNormalization)            128)
#
#  add_20 (Add)                   (None, None, None,   0           ['activation_58[0][0]',
#                                 128)                              'instance_normalization_41[0][0]
#                                                                  ']
#
#  activation_60 (Activation)     (None, None, None,   0           ['add_20[0][0]']
#                                 128)
#
#  conv2d_57 (Conv2D)             (None, None, None,   147456      ['activation_60[0][0]']
#                                 128)
#
#  instance_normalization_42 (Ins  (None, None, None,   0          ['conv2d_57[0][0]']
#  tanceNormalization)            128)
#
#  activation_61 (Activation)     (None, None, None,   0           ['instance_normalization_42[0][0]
#                                 128)                             ']
#
#  dropout_21 (Dropout)           (None, None, None,   0           ['activation_61[0][0]']
#                                 128)
#
#  conv2d_58 (Conv2D)             (None, None, None,   147456      ['dropout_21[0][0]']
#                                 128)
#
#  instance_normalization_43 (Ins  (None, None, None,   0          ['conv2d_58[0][0]']
#  tanceNormalization)            128)
#
#  add_21 (Add)                   (None, None, None,   0           ['activation_60[0][0]',
#                                 128)                              'instance_normalization_43[0][0]
#                                                                  ']
#
#  activation_62 (Activation)     (None, None, None,   0           ['add_21[0][0]']
#                                 128)
#
#  conv2d_59 (Conv2D)             (None, None, None,   147456      ['activation_62[0][0]']
#                                 128)
#
#  instance_normalization_44 (Ins  (None, None, None,   0          ['conv2d_59[0][0]']
#  tanceNormalization)            128)
#
#  activation_63 (Activation)     (None, None, None,   0           ['instance_normalization_44[0][0]
#                                 128)                             ']
#
#  dropout_22 (Dropout)           (None, None, None,   0           ['activation_63[0][0]']
#                                 128)
#
#  conv2d_60 (Conv2D)             (None, None, None,   147456      ['dropout_22[0][0]']
#                                 128)
#
#  instance_normalization_45 (Ins  (None, None, None,   0          ['conv2d_60[0][0]']
#  tanceNormalization)            128)
#
#  add_22 (Add)                   (None, None, None,   0           ['activation_62[0][0]',
#                                 128)                              'instance_normalization_45[0][0]
#                                                                  ']
#
#  activation_64 (Activation)     (None, None, None,   0           ['add_22[0][0]']
#                                 128)
#
#  conv2d_61 (Conv2D)             (None, None, None,   147456      ['activation_64[0][0]']
#                                 128)
#
#  instance_normalization_46 (Ins  (None, None, None,   0          ['conv2d_61[0][0]']
#  tanceNormalization)            128)
#
#  activation_65 (Activation)     (None, None, None,   0           ['instance_normalization_46[0][0]
#                                 128)                             ']
#
#  dropout_23 (Dropout)           (None, None, None,   0           ['activation_65[0][0]']
#                                 128)
#
#  conv2d_62 (Conv2D)             (None, None, None,   147456      ['dropout_23[0][0]']
#                                 128)
#
#  instance_normalization_47 (Ins  (None, None, None,   0          ['conv2d_62[0][0]']
#  tanceNormalization)            128)
#
#  add_23 (Add)                   (None, None, None,   0           ['activation_64[0][0]',
#                                 128)                              'instance_normalization_47[0][0]
#                                                                  ']
#
#  activation_66 (Activation)     (None, None, None,   0           ['add_23[0][0]']
#                                 128)
#
#  conv2d_63 (Conv2D)             (None, None, None,   147456      ['activation_66[0][0]']
#                                 128)
#
#  instance_normalization_48 (Ins  (None, None, None,   0          ['conv2d_63[0][0]']
#  tanceNormalization)            128)
#
#  activation_67 (Activation)     (None, None, None,   0           ['instance_normalization_48[0][0]
#                                 128)                             ']
#
#  dropout_24 (Dropout)           (None, None, None,   0           ['activation_67[0][0]']
#                                 128)
#
#  conv2d_64 (Conv2D)             (None, None, None,   147456      ['dropout_24[0][0]']
#                                 128)
#
#  instance_normalization_49 (Ins  (None, None, None,   0          ['conv2d_64[0][0]']
#  tanceNormalization)            128)
#
#  add_24 (Add)                   (None, None, None,   0           ['activation_66[0][0]',
#                                 128)                              'instance_normalization_49[0][0]
#                                                                  ']
#
#  activation_68 (Activation)     (None, None, None,   0           ['add_24[0][0]']
#                                 128)
#
#  conv2d_65 (Conv2D)             (None, None, None,   147456      ['activation_68[0][0]']
#                                 128)
#
#  instance_normalization_50 (Ins  (None, None, None,   0          ['conv2d_65[0][0]']
#  tanceNormalization)            128)
#
#  activation_69 (Activation)     (None, None, None,   0           ['instance_normalization_50[0][0]
#                                 128)                             ']
#
#  dropout_25 (Dropout)           (None, None, None,   0           ['activation_69[0][0]']
#                                 128)
#
#  conv2d_66 (Conv2D)             (None, None, None,   147456      ['dropout_25[0][0]']
#                                 128)
#
#  instance_normalization_51 (Ins  (None, None, None,   0          ['conv2d_66[0][0]']
#  tanceNormalization)            128)
#
#  add_25 (Add)                   (None, None, None,   0           ['activation_68[0][0]',
#                                 128)                              'instance_normalization_51[0][0]
#                                                                  ']
#
#  activation_70 (Activation)     (None, None, None,   0           ['add_25[0][0]']
#                                 128)
#
#  conv2d_67 (Conv2D)             (None, None, None,   147456      ['activation_70[0][0]']
#                                 128)
#
#  instance_normalization_52 (Ins  (None, None, None,   0          ['conv2d_67[0][0]']
#  tanceNormalization)            128)
#
#  activation_71 (Activation)     (None, None, None,   0           ['instance_normalization_52[0][0]
#                                 128)                             ']
#
#  dropout_26 (Dropout)           (None, None, None,   0           ['activation_71[0][0]']
#                                 128)
#
#  conv2d_68 (Conv2D)             (None, None, None,   147456      ['dropout_26[0][0]']
#                                 128)
#
#  instance_normalization_53 (Ins  (None, None, None,   0          ['conv2d_68[0][0]']
#  tanceNormalization)            128)
#
#  add_26 (Add)                   (None, None, None,   0           ['activation_70[0][0]',
#                                 128)                              'instance_normalization_53[0][0]
#                                                                  ']
#
#  activation_72 (Activation)     (None, None, None,   0           ['add_26[0][0]']
#                                 128)
#
#  concatenate_5 (Concatenate)    (None, None, None,   0           ['activation_72[0][0]',
#                                 256)                              'activation_54[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, None, None,   262208     ['concatenate_5[0][0]']
#  spose)                         64)
#
#  activation_73 (Activation)     (None, None, None,   0           ['conv2d_transpose_6[0][0]']
#                                 64)
#
#  conv2d_transpose_7 (Conv2DTran  (None, None, None,   32800      ['activation_73[0][0]']
#  spose)                         32)
#
#  activation_74 (Activation)     (None, None, None,   0           ['conv2d_transpose_7[0][0]']
#                                 32)
#
#  conv2d_transpose_8 (Conv2DTran  (None, None, None,   8208       ['activation_74[0][0]']
#  spose)                         16)
#
#  activation_75 (Activation)     (None, None, None,   0           ['conv2d_transpose_8[0][0]']
#                                 16)
#
#  conv2d_69 (Conv2D)             (None, None, None,   432         ['activation_75[0][0]']
#                                 3)
#
#  tf.math.subtract_1 (TFOpLambda  (None, None, None,   0          ['blur_image[0][0]',
#  )                              3)                                'conv2d_69[0][0]']
#
#  concatenate_6 (Concatenate)    (None, None, None,   0           ['conv2d_69[0][0]',
#                                 6)                                'tf.math.subtract_1[0][0]']
#
#  conv2d_70 (Conv2D)             (None, None, None,   1296        ['concatenate_6[0][0]']
#                                 24)
#
#  activation_76 (Activation)     (None, None, None,   0           ['conv2d_70[0][0]']
#                                 24)
#
#  conv2d_71 (Conv2D)             (None, None, None,   10368       ['activation_76[0][0]']
#                                 48)
#
#  activation_77 (Activation)     (None, None, None,   0           ['conv2d_71[0][0]']
#                                 48)
#
#  conv2d_72 (Conv2D)             (None, None, None,   41472       ['activation_77[0][0]']
#                                 96)
#
#  activation_78 (Activation)     (None, None, None,   0           ['conv2d_72[0][0]']
#                                 96)
#
#  conv2d_73 (Conv2D)             (None, None, None,   165888      ['activation_78[0][0]']
#                                 192)
#
#  activation_79 (Activation)     (None, None, None,   0           ['conv2d_73[0][0]']
#                                 192)
#
#  conv2d_74 (Conv2D)             (None, None, None,   331776      ['activation_79[0][0]']
#                                 192)
#
#  activation_80 (Activation)     (None, None, None,   0           ['conv2d_74[0][0]']
#                                 192)
#
#  conv2d_75 (Conv2D)             (None, None, None,   331776      ['activation_80[0][0]']
#                                 192)
#
#  instance_normalization_54 (Ins  (None, None, None,   0          ['conv2d_75[0][0]']
#  tanceNormalization)            192)
#
#  activation_81 (Activation)     (None, None, None,   0           ['instance_normalization_54[0][0]
#                                 192)                             ']
#
#  dropout_27 (Dropout)           (None, None, None,   0           ['activation_81[0][0]']
#                                 192)
#
#  conv2d_76 (Conv2D)             (None, None, None,   331776      ['dropout_27[0][0]']
#                                 192)
#
#  instance_normalization_55 (Ins  (None, None, None,   0          ['conv2d_76[0][0]']
#  tanceNormalization)            192)
#
#  add_27 (Add)                   (None, None, None,   0           ['activation_80[0][0]',
#                                 192)                              'instance_normalization_55[0][0]
#                                                                  ']
#
#  activation_82 (Activation)     (None, None, None,   0           ['add_27[0][0]']
#                                 192)
#
#  conv2d_77 (Conv2D)             (None, None, None,   331776      ['activation_82[0][0]']
#                                 192)
#
#  instance_normalization_56 (Ins  (None, None, None,   0          ['conv2d_77[0][0]']
#  tanceNormalization)            192)
#
#  activation_83 (Activation)     (None, None, None,   0           ['instance_normalization_56[0][0]
#                                 192)                             ']
#
#  dropout_28 (Dropout)           (None, None, None,   0           ['activation_83[0][0]']
#                                 192)
#
#  conv2d_78 (Conv2D)             (None, None, None,   331776      ['dropout_28[0][0]']
#                                 192)
#
#  instance_normalization_57 (Ins  (None, None, None,   0          ['conv2d_78[0][0]']
#  tanceNormalization)            192)
#
#  add_28 (Add)                   (None, None, None,   0           ['activation_82[0][0]',
#                                 192)                              'instance_normalization_57[0][0]
#                                                                  ']
#
#  activation_84 (Activation)     (None, None, None,   0           ['add_28[0][0]']
#                                 192)
#
#  conv2d_79 (Conv2D)             (None, None, None,   331776      ['activation_84[0][0]']
#                                 192)
#
#  instance_normalization_58 (Ins  (None, None, None,   0          ['conv2d_79[0][0]']
#  tanceNormalization)            192)
#
#  activation_85 (Activation)     (None, None, None,   0           ['instance_normalization_58[0][0]
#                                 192)                             ']
#
#  dropout_29 (Dropout)           (None, None, None,   0           ['activation_85[0][0]']
#                                 192)
#
#  conv2d_80 (Conv2D)             (None, None, None,   331776      ['dropout_29[0][0]']
#                                 192)
#
#  instance_normalization_59 (Ins  (None, None, None,   0          ['conv2d_80[0][0]']
#  tanceNormalization)            192)
#
#  add_29 (Add)                   (None, None, None,   0           ['activation_84[0][0]',
#                                 192)                              'instance_normalization_59[0][0]
#                                                                  ']
#
#  activation_86 (Activation)     (None, None, None,   0           ['add_29[0][0]']
#                                 192)
#
#  conv2d_81 (Conv2D)             (None, None, None,   331776      ['activation_86[0][0]']
#                                 192)
#
#  instance_normalization_60 (Ins  (None, None, None,   0          ['conv2d_81[0][0]']
#  tanceNormalization)            192)
#
#  activation_87 (Activation)     (None, None, None,   0           ['instance_normalization_60[0][0]
#                                 192)                             ']
#
#  dropout_30 (Dropout)           (None, None, None,   0           ['activation_87[0][0]']
#                                 192)
#
#  conv2d_82 (Conv2D)             (None, None, None,   331776      ['dropout_30[0][0]']
#                                 192)
#
#  instance_normalization_61 (Ins  (None, None, None,   0          ['conv2d_82[0][0]']
#  tanceNormalization)            192)
#
#  add_30 (Add)                   (None, None, None,   0           ['activation_86[0][0]',
#                                 192)                              'instance_normalization_61[0][0]
#                                                                  ']
#
#  activation_88 (Activation)     (None, None, None,   0           ['add_30[0][0]']
#                                 192)
#
#  conv2d_83 (Conv2D)             (None, None, None,   331776      ['activation_88[0][0]']
#                                 192)
#
#  instance_normalization_62 (Ins  (None, None, None,   0          ['conv2d_83[0][0]']
#  tanceNormalization)            192)
#
#  activation_89 (Activation)     (None, None, None,   0           ['instance_normalization_62[0][0]
#                                 192)                             ']
#
#  dropout_31 (Dropout)           (None, None, None,   0           ['activation_89[0][0]']
#                                 192)
#
#  conv2d_84 (Conv2D)             (None, None, None,   331776      ['dropout_31[0][0]']
#                                 192)
#
#  instance_normalization_63 (Ins  (None, None, None,   0          ['conv2d_84[0][0]']
#  tanceNormalization)            192)
#
#  add_31 (Add)                   (None, None, None,   0           ['activation_88[0][0]',
#                                 192)                              'instance_normalization_63[0][0]
#                                                                  ']
#
#  activation_90 (Activation)     (None, None, None,   0           ['add_31[0][0]']
#                                 192)
#
#  conv2d_85 (Conv2D)             (None, None, None,   331776      ['activation_90[0][0]']
#                                 192)
#
#  instance_normalization_64 (Ins  (None, None, None,   0          ['conv2d_85[0][0]']
#  tanceNormalization)            192)
#
#  activation_91 (Activation)     (None, None, None,   0           ['instance_normalization_64[0][0]
#                                 192)                             ']
#
#  dropout_32 (Dropout)           (None, None, None,   0           ['activation_91[0][0]']
#                                 192)
#
#  conv2d_86 (Conv2D)             (None, None, None,   331776      ['dropout_32[0][0]']
#                                 192)
#
#  instance_normalization_65 (Ins  (None, None, None,   0          ['conv2d_86[0][0]']
#  tanceNormalization)            192)
#
#  add_32 (Add)                   (None, None, None,   0           ['activation_90[0][0]',
#                                 192)                              'instance_normalization_65[0][0]
#                                                                  ']
#
#  activation_92 (Activation)     (None, None, None,   0           ['add_32[0][0]']
#                                 192)
#
#  conv2d_87 (Conv2D)             (None, None, None,   331776      ['activation_92[0][0]']
#                                 192)
#
#  instance_normalization_66 (Ins  (None, None, None,   0          ['conv2d_87[0][0]']
#  tanceNormalization)            192)
#
#  activation_93 (Activation)     (None, None, None,   0           ['instance_normalization_66[0][0]
#                                 192)                             ']
#
#  dropout_33 (Dropout)           (None, None, None,   0           ['activation_93[0][0]']
#                                 192)
#
#  conv2d_88 (Conv2D)             (None, None, None,   331776      ['dropout_33[0][0]']
#                                 192)
#
#  instance_normalization_67 (Ins  (None, None, None,   0          ['conv2d_88[0][0]']
#  tanceNormalization)            192)
#
#  add_33 (Add)                   (None, None, None,   0           ['activation_92[0][0]',
#                                 192)                              'instance_normalization_67[0][0]
#                                                                  ']
#
#  activation_94 (Activation)     (None, None, None,   0           ['add_33[0][0]']
#                                 192)
#
#  conv2d_89 (Conv2D)             (None, None, None,   331776      ['activation_94[0][0]']
#                                 192)
#
#  instance_normalization_68 (Ins  (None, None, None,   0          ['conv2d_89[0][0]']
#  tanceNormalization)            192)
#
#  activation_95 (Activation)     (None, None, None,   0           ['instance_normalization_68[0][0]
#                                 192)                             ']
#
#  dropout_34 (Dropout)           (None, None, None,   0           ['activation_95[0][0]']
#                                 192)
#
#  conv2d_90 (Conv2D)             (None, None, None,   331776      ['dropout_34[0][0]']
#                                 192)
#
#  instance_normalization_69 (Ins  (None, None, None,   0          ['conv2d_90[0][0]']
#  tanceNormalization)            192)
#
#  add_34 (Add)                   (None, None, None,   0           ['activation_94[0][0]',
#                                 192)                              'instance_normalization_69[0][0]
#                                                                  ']
#
#  activation_96 (Activation)     (None, None, None,   0           ['add_34[0][0]']
#                                 192)
#
#  conv2d_91 (Conv2D)             (None, None, None,   331776      ['activation_96[0][0]']
#                                 192)
#
#  instance_normalization_70 (Ins  (None, None, None,   0          ['conv2d_91[0][0]']
#  tanceNormalization)            192)
#
#  activation_97 (Activation)     (None, None, None,   0           ['instance_normalization_70[0][0]
#                                 192)                             ']
#
#  dropout_35 (Dropout)           (None, None, None,   0           ['activation_97[0][0]']
#                                 192)
#
#  conv2d_92 (Conv2D)             (None, None, None,   331776      ['dropout_35[0][0]']
#                                 192)
#
#  instance_normalization_71 (Ins  (None, None, None,   0          ['conv2d_92[0][0]']
#  tanceNormalization)            192)
#
#  add_35 (Add)                   (None, None, None,   0           ['activation_96[0][0]',
#                                 192)                              'instance_normalization_71[0][0]
#                                                                  ']
#
#  activation_98 (Activation)     (None, None, None,   0           ['add_35[0][0]']
#                                 192)
#
#  concatenate_7 (Concatenate)    (None, None, None,   0           ['activation_79[0][0]',
#                                 384)                              'activation_98[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, None, None,   589920     ['concatenate_7[0][0]']
#  spose)                         96)
#
#  activation_99 (Activation)     (None, None, None,   0           ['conv2d_transpose_9[0][0]']
#                                 96)
#
#  concatenate_8 (Concatenate)    (None, None, None,   0           ['activation_78[0][0]',
#                                 192)                              'activation_99[0][0]']
#
#  conv2d_transpose_10 (Conv2DTra  (None, None, None,   147504     ['concatenate_8[0][0]']
#  nspose)                        48)
#
#  activation_100 (Activation)    (None, None, None,   0           ['conv2d_transpose_10[0][0]']
#                                 48)
#
#  concatenate_9 (Concatenate)    (None, None, None,   0           ['activation_77[0][0]',
#                                 96)                               'activation_100[0][0]']
#
#  conv2d_transpose_11 (Conv2DTra  (None, None, None,   36888      ['concatenate_9[0][0]']
#  nspose)                        24)
#
#  activation_101 (Activation)    (None, None, None,   0           ['conv2d_transpose_11[0][0]']
#                                 24)
#
#  conv2d_93 (Conv2D)             (None, None, None,   648         ['activation_101[0][0]']
#                                 3)
#
# ==================================================================================================
# Total params: 10,352,784
# Trainable params: 10,352,784
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #Load the BGGAN model

# %%
bokeh_GT = "/content/bokeh/"
bokeh_Original = "/content/original/"
model_path = "/content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/model/"
outputdir = "/content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/"

# %%
generator = xnet()

checkpoint = tf.train.Checkpoint(generator=generator)
checkpoint.restore(tf.train.latest_checkpoint(model_path))

# %%
# !unzip /content/drive/Shareddrives/DeepLearning_VisionAnalytics/Dataset/TestBokehFree.zip > logs.txt

# %%
# !unzip /content/drive/Shareddrives/DeepLearning_VisionAnalytics/Dataset/Training.zip > logs.txt

# %% [markdown]
# #Generate 100 bokeh images based on BGGAN model

# %%
generator.trainable = False
if not os.path.exists(outputdir):
    os.mkdir(outputdir)
factor = 8 
for i in range(100):
    img = bokeh_Original + str(i) + ".jpg"
    # read img
    out_name = os.path.basename(img)
    inputs = tf.io.read_file(img)
    blur_image = tf.io.decode_jpeg(inputs,3)
    h,w,_ = blur_image.shape
    if w%factor!=0:
        blur_image = tf.image.resize(blur_image,[1024,w+factor-int(w)%factor],method=tf.image.ResizeMethod.BICUBIC)
    blur_image = tf.cast(blur_image, tf.float32)
    blur_image = (blur_image / 127.5) - 1.0
    blur_image = tf.expand_dims(blur_image,0)

    # inference
    output =  generator(blur_image)[0]

    # save model
    output = tf.squeeze(output)
    output = (output+1.0)*127.5
    # output = output[0,:h,:w,::-1]
    output = tf.image.resize(output,[h,w],method=tf.image.ResizeMethod.BICUBIC)
    output = tf.cast(output, tf.uint8)
    output = tf.io.encode_jpeg(output)

    tf.io.write_file(os.path.join(outputdir, out_name), output)
    print('processing:',i+1, '/100, save img:',os.path.join(outputdir, out_name))
print('processed')
# Out:
# processing: 1 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/0.jpg
# processing: 2 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/1.jpg
# processing: 3 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/2.jpg
# processing: 4 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/3.jpg
# processing: 5 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/4.jpg
# processing: 6 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/5.jpg
# processing: 7 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/6.jpg
# processing: 8 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/7.jpg
# processing: 9 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/8.jpg
# processing: 10 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/9.jpg
# processing: 11 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/10.jpg
# processing: 12 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/11.jpg
# processing: 13 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/12.jpg
# processing: 14 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/13.jpg
# processing: 15 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/14.jpg
# processing: 16 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/15.jpg
# processing: 17 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/16.jpg
# processing: 18 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/17.jpg
# processing: 19 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/18.jpg
# processing: 20 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/19.jpg
# processing: 21 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/20.jpg
# processing: 22 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/21.jpg
# processing: 23 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/22.jpg
# processing: 24 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/23.jpg
# processing: 25 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/24.jpg
# processing: 26 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/25.jpg
# processing: 27 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/26.jpg
# processing: 28 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/27.jpg
# processing: 29 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/28.jpg
# processing: 30 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/29.jpg
# processing: 31 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/30.jpg
# processing: 32 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/31.jpg
# processing: 33 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/32.jpg
# processing: 34 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/33.jpg
# processing: 35 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/34.jpg
# processing: 36 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/35.jpg
# processing: 37 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/36.jpg
# processing: 38 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/37.jpg
# processing: 39 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/38.jpg
# processing: 40 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/39.jpg
# processing: 41 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/40.jpg
# processing: 42 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/41.jpg
# processing: 43 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/42.jpg
# processing: 44 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/43.jpg
# processing: 45 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/44.jpg
# processing: 46 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/45.jpg
# processing: 47 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/46.jpg
# processing: 48 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/47.jpg
# processing: 49 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/48.jpg
# processing: 50 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/49.jpg
# processing: 51 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/50.jpg
# processing: 52 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/51.jpg
# processing: 53 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/52.jpg
# processing: 54 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/53.jpg
# processing: 55 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/54.jpg
# processing: 56 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/55.jpg
# processing: 57 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/56.jpg
# processing: 58 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/57.jpg
# processing: 59 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/58.jpg
# processing: 60 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/59.jpg
# processing: 61 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/60.jpg
# processing: 62 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/61.jpg
# processing: 63 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/62.jpg
# processing: 64 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/63.jpg
# processing: 65 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/64.jpg
# processing: 66 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/65.jpg
# processing: 67 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/66.jpg
# processing: 68 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/67.jpg
# processing: 69 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/68.jpg
# processing: 70 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/69.jpg
# processing: 71 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/70.jpg
# processing: 72 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/71.jpg
# processing: 73 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/72.jpg
# processing: 74 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/73.jpg
# processing: 75 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/74.jpg
# processing: 76 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/75.jpg
# processing: 77 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/76.jpg
# processing: 78 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/77.jpg
# processing: 79 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/78.jpg
# processing: 80 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/79.jpg
# processing: 81 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/80.jpg
# processing: 82 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/81.jpg
# processing: 83 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/82.jpg
# processing: 84 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/83.jpg
# processing: 85 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/84.jpg
# processing: 86 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/85.jpg
# processing: 87 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/86.jpg
# processing: 88 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/87.jpg
# processing: 89 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/88.jpg
# processing: 90 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/89.jpg
# processing: 91 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/90.jpg
# processing: 92 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/91.jpg
# processing: 93 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/92.jpg
# processing: 94 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/93.jpg
# processing: 95 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/94.jpg
# processing: 96 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/95.jpg
# processing: 97 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/96.jpg
# processing: 98 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/97.jpg
# processing: 99 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/98.jpg
# processing: 100 /100, save img: /content/drive/Shareddrives/DeepLearning_VisionAnalytics/BG_GAN_Model/OurTestset/OriginalModelOutputs/99.jpg
# processed

# %% [markdown]
# # Evaluation

# %% [markdown]
# ##PSNR

# %%
from math import log10, sqrt
import cv2
import numpy as np
  
def PSNR(original, compressed):
    mse = np.mean((original - compressed) ** 2)
    if(mse == 0):  # MSE is zero means no noise is present in the signal .
                  # Therefore PSNR have no importance.
        return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse))
    return psnr

# %%
values = []
for i in range(100):
  img1 = bokeh_GT + str(i) + ".jpg"
  img2 = outputdir + str(i) + ".jpg"

  ground_truth_bokeh = cv2.imread(img1)
  generated_bokeh = cv2.imread(img2)
  
  values.append(PSNR(ground_truth_bokeh, generated_bokeh))
values = np.array(values)
print(f"Avg PSNR value is {np.average(values)} dB")
# Out:
# Avg PSNR value is 30.96744956123231 dB

# %% [markdown]
# ## SSIM

# %%
import math
import numpy as np
import cv2

def ssim(img1, img2):
    C1 = (0.01 * 255)**2
    C2 = (0.03 * 255)**2

    img1 = img1.astype(np.float64)
    img2 = img2.astype(np.float64)
    kernel = cv2.getGaussianKernel(11, 1.5)
    window = np.outer(kernel, kernel.transpose())

    mu1 = cv2.filter2D(img1, -1, window)[5:-5, 5:-5]  # valid
    mu2 = cv2.filter2D(img2, -1, window)[5:-5, 5:-5]
    mu1_sq = mu1**2
    mu2_sq = mu2**2
    mu1_mu2 = mu1 * mu2
    sigma1_sq = cv2.filter2D(img1**2, -1, window)[5:-5, 5:-5] - mu1_sq
    sigma2_sq = cv2.filter2D(img2**2, -1, window)[5:-5, 5:-5] - mu2_sq
    sigma12 = cv2.filter2D(img1 * img2, -1, window)[5:-5, 5:-5] - mu1_mu2

    ssim_map = ((2 * mu1_mu2 + C1) * (2 * sigma12 + C2)) / ((mu1_sq + mu2_sq + C1) *
                                                            (sigma1_sq + sigma2_sq + C2))
    return ssim_map.mean()


def calculate_ssim(img1, img2):
    '''calculate SSIM
    the same outputs as MATLAB's
    img1, img2: [0, 255]
    '''
    if not img1.shape == img2.shape:
        raise ValueError('Input images must have the same dimensions.')
    if img1.ndim == 2:
        return ssim(img1, img2)
    elif img1.ndim == 3:
        if img1.shape[2] == 3:
            ssims = []
            for i in range(3):
                ssims.append(ssim(img1, img2))
            return np.array(ssims).mean()
        elif img1.shape[2] == 1:
            return ssim(np.squeeze(img1), np.squeeze(img2))
    else:
        raise ValueError('Wrong input image dimensions.')

# %%
values = []
for i in range(100):
  img1 = bokeh_GT + str(i) + ".jpg"
  img2 = outputdir + str(i) + ".jpg"

  ground_truth_bokeh = cv2.imread(img1)
  generated_bokeh = cv2.imread(img2)
  
  values.append(calculate_ssim(ground_truth_bokeh, generated_bokeh))
values = np.array(values)
print(f"Avg SSIM value is {np.average(values)} dB")
# Out:
# Avg SSIM value is 0.8972150874928632 dB
